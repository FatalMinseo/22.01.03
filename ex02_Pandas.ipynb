# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# Pandas 의 Serises 생성
series1 = pd.Series([1,2,3,4,5])
series1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# index 지정해서 Series 생성
series2=pd.Series([1,2,3,4,5],index=['일','이','삼','사','오'])
series2
# Out:
# 일    1
# 이    2
# 삼    3
# 사    4
# 오    5
# dtype: int64

# %%
population = pd.Series([9904312,3448737,2890451,2466052], index=['서울','부산','인천','대구'])
population
# Out:
# 서울    9904312
# 부산    3448737
# 인천    2890451
# 대구    2466052
# dtype: int64

# %%
# Series 정보 확인
# 값, 인덱스, 타입
# value, index, dtype
population.values
# Out:
# array([9904312, 3448737, 2890451, 2466052], dtype=int64)

# %%
population.dtype
# Out:
# dtype('int64')

# %%
population.index
# Out:
# Index(['서울', '부산', '인천', '대구'], dtype='object')

# %%
# Series의 컬럼 이름 지정
population.name='인구'
population
# Out:
# 서울    9904312
# 부산    3448737
# 인천    2890451
# 대구    2466052
# Name: 인구, dtype: int64

# %%
population.index.name='도시'
population
# Out:
# 도시
# 서울    9904312
# 부산    3448737
# 인천    2890451
# 대구    2466052
# Name: 인구, dtype: int64

# %%
# 시리즈 연산
population/1000000
# Out:
# 도시
# 서울    9.904312
# 부산    3.448737
# 인천    2.890451
# 대구    2.466052
# Name: 인구, dtype: float64

# %%
# 시리즈 인덱싱
population[1] # 인덱스 번호 사용
# Out:
# 3448737

# %%
population['부산'] # 지정한 인덱스 사용
# Out:
# 3448737

# %%
# 리스트를 활용한 인덱싱
# 순서나 횟수에 상관 없음
population[['대구','서울','부산','대구']]
# Out:
# 도시
# 대구    2466052
# 서울    9904312
# 부산    3448737
# 대구    2466052
# Name: 인구, dtype: int64

# %%
population[[0,3,1]]
# Out:
# 도시
# 서울    9904312
# 대구    2466052
# 부산    3448737
# Name: 인구, dtype: int64

# %%
# Boolean 인덱싱
# 인구 수가 250만 이상인 도시의 정보 출력

# %%
population[population>=2500000]
# Out:
# 도시
# 서울    9904312
# 부산    3448737
# 인천    2890451
# Name: 인구, dtype: int64

# %%
# 인구수가 500만 이하의 도시 정보 출력
population[population<=5000000]
# Out:
# 도시
# 부산    3448737
# 인천    2890451
# 대구    2466052
# Name: 인구, dtype: int64

# %%
population[(population<=5000000) & (population>=2500000)]
# Out:
# 도시
# 부산    3448737
# 인천    2890451
# Name: 인구, dtype: int64

# %%
population[population<=5000000][population>=2500000]
# Out:
# 도시
# 부산    3448737
# 인천    2890451
# Name: 인구, dtype: int64

# %%
# 슬라이싱
# 인덱스 번호로 슬라이싱[시작한 수 : 끝나는 수]
# 지정한 인덱스로 슬라이싱[시작한 값 : 끝나는 값]
pop=population['부산':'대구']
pop
# Out:
# 도시
# 부산    3448737
# 인천    2890451
# 대구    2466052
# Name: 인구, dtype: int64

# %%
# 딕셔너리 객체로 Series 생성
# 인덱스 부여가 자동으로 완성
# key = 인덱스
# values = 값
data = {'서울':9631482,'부산':3393191,'인천':2632035,'대전' : 1490158}
population2 = pd.Series(data)
population2
# Out:
# 서울    9631482
# 부산    3393191
# 인천    2632035
# 대전    1490158
# dtype: int64

# %%
# population2 : 2010년 인구
# population : 2015년 인구
# 2015년도와 2010년도의 인구 증가ds=를 계산
ds=population - population2
ds
# Out:
# 대구         NaN
# 대전         NaN
# 부산     55546.0
# 서울    272830.0
# 인천    258416.0
# dtype: float64

# %%
print(population.index)
print(population2.index)
# Out:
# Index(['서울', '부산', '인천', '대구'], dtype='object', name='도시')
# Index(['서울', '부산', '인천', '대전'], dtype='object')

# %%
# notnull() : null이 아니면 True, null이면 False
# isnull() : null이 아니면 False, null이면 True

# %%
ds[ds.notnull()]
# Out:
# 부산     55546.0
# 서울    272830.0
# 인천    258416.0
# dtype: float64

# %%
ds[ds.isnull()]
# Out:
# 대구   NaN
# 대전   NaN
# dtype: float64

# %%
# 2015년도와 2010년도의 인구 증가율 계산
# 단, 없는 값은 출력 X
# (2015년 인구 -2010년 인구)/2010년 인구 *100

# %%
rs=ds/population2*100
rs[rs.notnull()]
# Out:
# 부산    1.636984
# 서울    2.832690
# 인천    9.818107
# dtype: float64

# %%
# Series값 갱신 추가 삭제
# 대구 값 갱신
rs['대구']=1.41

# %%
rs
# Out:
# 대구    1.410000
# 대전         NaN
# 부산    1.636984
# 서울    2.832690
# 인천    9.818107
# dtype: float64

# %%
# 값 추가
rs['광주']=2.08
rs
# Out:
# 대구    1.410000
# 대전         NaN
# 부산    1.636984
# 서울    2.832690
# 인천    9.818107
# 광주    2.080000
# dtype: float64

# %%
del rs['대전']
rs
# Out:
# 대구    1.410000
# 부산    1.636984
# 서울    2.832690
# 인천    9.818107
# 광주    2.080000
# dtype: float64

# %% [markdown]
# ### DataFrame

# %%
# 딕셔너리를 통해서 DataFrame만들기
data={
    "2015" : [9904312,3448737,2890451,2466052],
    "2010" : [9631482,3393191,2632035,2431774]
}
df = pd.DataFrame(data)
df
# Out:
#       2015     2010
# 0  9904312  9631482
# 1  3448737  3393191
# 2  2890451  2632035
# 3  2466052  2431774

# %%
# DataFrame 생성 후 index 설정
df.index = ['서울', '부산','인천','대구']
df
# Out:
#        2015     2010
# 서울  9904312  9631482
# 부산  3448737  3393191
# 인천  2890451  2632035
# 대구  2466052  2431774

# %%
# DataFrame 생성 시 index 지정, column 지정
data =[
    [9904312,3448737,2890451,2466052],
    [9631482,3393191,2632035,2431774]
    
]
ind = ['2015','2010']
col = ['서울', '부산','인천','대구']
df2=pd.DataFrame(data, index=ind, columns=col)
df2
# Out:
#            서울       부산       인천       대구
# 2015  9904312  3448737  2890451  2466052
# 2010  9631482  3393191  2632035  2431774

# %%
# 전치
# T : 데이터프레임의 속성 pandas에서만 적용
# transpose() : 전치가 가능한 모든 데이터에 적용 가능

df22=df2.transpose()
df22
# Out:
#        2015     2010
# 서울  9904312  9631482
# 부산  3448737  3393191
# 인천  2890451  2632035
# 대구  2466052  2431774

# %%
data2=[
    [9904312,9631482],
    [3448737,3393191],
    [2890451,2632035],
    [2466052,2431774]
]
ind2=['서울', '부산','인천','대구']
col2=['2015','2010']
df3=pd.DataFrame(data2, index=ind2, columns=col2)
df3
# Out:
#        2015     2010
# 서울  9904312  9631482
# 부산  3448737  3393191
# 인천  2890451  2632035
# 대구  2466052  2431774

# %%
# 데이터프레임 정보 확인
# 값 확인 : values
# 인덱스 확인 : index
# 컬럼확인 : columns

# %%
df3.values
# Out:
# array([[9904312, 9631482],
#        [3448737, 3393191],
#        [2890451, 2632035],
#        [2466052, 2431774]], dtype=int64)

# %%
df3.index
# Out:
# Index(['서울', '부산', '인천', '대구'], dtype='object')

# %%
df3.columns
# Out:
# Index(['2015', '2010'], dtype='object')

# %%
# 데이터프레임에 값 추가
# 컬럼을 기준으로 값 추가
# 기존에 가지고 있는 컬럼을 입력 시 값의 수정이 이루어짐
df3['2005']=[9762546,3512547,2517680,2456016]
df3
# Out:
#        2015     2010     2005
# 서울  9904312  9631482  9762546
# 부산  3448737  3393191  3512547
# 인천  2890451  2632035  2517680
# 대구  2466052  2431774  2456016

# %%
# 인덱싱 슬라이싱
# 컬럼으로 인덱싱하기
df3["2010"] # 하나의 컬럼 출력 시 Series로 출력
# Out:
# 서울    9631482
# 부산    3393191
# 인천    2632035
# 대구    2431774
# Name: 2010, dtype: int64

# %%
# 리스트를 사용한 인덱싱
# 데이터 프레임으로 출력
df3[["2010"]]
# Out:
#        2010
# 서울  9631482
# 부산  3393191
# 인천  2632035
# 대구  2431774

# %%
# 컬럼을 기준으로 하는 슬라이싱 숫자 컬럼명 상관없음
# 컬럼을 기준 인덱싱은 숫자x 컬럼명을 기준으로
df3[0:2]
# Out:
#        2015     2010     2005
# 서울  9904312  9631482  9762546
# 부산  3448737  3393191  3512547

# %%
# 인덱서
# iloc : 인덱스 번호 사용
# loc : 지정한 인덱스 사용

# %%
# loc[ index , columns ]
df3.loc["서울":"부산", "2015" :"2010"]
# Out:
#        2015     2010
# 서울  9904312  9631482
# 부산  3448737  3393191

# %%
# iloc 인덱서를 사용해서 동일한 결과값 출력
df3.iloc[0:2, 0:2]
# Out:
#        2015     2010
# 서울  9904312  9631482
# 부산  3448737  3393191

# %%
# 데이터프레임 Boolean인덱싱
# 2010년 인구가 2500000 이상인 데이터 출력
bol =df3.loc[:,"2010"]>=2500000
bol
# Out:
# 서울     True
# 부산     True
# 인천     True
# 대구    False
# Name: 2010, dtype: bool

# %%
df3.loc[bol,:]
# Out:
#        2015     2010     2005
# 서울  9904312  9631482  9762546
# 부산  3448737  3393191  3512547
# 인천  2890451  2632035  2517680

# %%
df3[df3["2010"]>2500000][["2010"]]
# Out:
#        2010
# 서울  9631482
# 부산  3393191
# 인천  2632035

# %%
# read_csv()
pn=pd.read_csv('population_number.csv', encoding='euc-kr', index_col ='도시')
pn
# Out:
#      지역     2015       2010       2005     2000
# 도시
# 서울  수도권  9904312  9631482.0  9762546.0  9853972
# 부산  경상권  3448737        NaN        NaN  3655437
# 인천  수도권  2890451  2632035.0        NaN  2466338
# 대구  경상권  2466052  2431774.0  2456016.0  2473990

# %%
# 값의 개수 세기
# value_counts
pn.loc[:,'지역'].value_counts()
# Out:
# 수도권    2
# 경상권    2
# Name: 지역, dtype: int64

# %%
# 정렬
# sort_values() : 값을 기준으로 정렬
pn.loc[:,'2010'].sort_values(ascending = False)
# Out:
# 도시
# 서울    9631482.0
# 인천    2632035.0
# 대구    2431774.0
# 부산          NaN
# Name: 2010, dtype: float64

# %%
pn.sort_values(by='2010')
# Out:
#      지역     2015       2010       2005     2000
# 도시
# 대구  경상권  2466052  2431774.0  2456016.0  2473990
# 인천  수도권  2890451  2632035.0        NaN  2466338
# 서울  수도권  9904312  9631482.0  9762546.0  9853972
# 부산  경상권  3448737        NaN        NaN  3655437

# %%
# 두개의 기준으로 데이터 살펴보기
pn.sort_values(by=['지역', '2010'])
# Out:
#      지역     2015       2010       2005     2000
# 도시
# 대구  경상권  2466052  2431774.0  2456016.0  2473990
# 부산  경상권  3448737        NaN        NaN  3655437
# 인천  수도권  2890451  2632035.0        NaN  2466338
# 서울  수도권  9904312  9631482.0  9762546.0  9853972

# %%
# 인덱스 값을 기준으로 정렬
pn.sort_index(ascending=False)
# Out:
#      지역     2015       2010       2005     2000
# 도시
# 인천  수도권  2890451  2632035.0        NaN  2466338
# 서울  수도권  9904312  9631482.0  9762546.0  9853972
# 부산  경상권  3448737        NaN        NaN  3655437
# 대구  경상권  2466052  2431774.0  2456016.0  2473990

# %%
sn=pd.read_csv('score.csv', encoding='euc-kr', index_col ='과목')
sn
# Out:
#     1반  2반  3반  4반
# 과목
# 수학  45  44  73  39
# 영어  76  92  45  69
# 국어  47  92  45  69
# 사회  92  81  85  40
# 과학  11  79  47  26

# %%
import numpy as np

# %%
# 학급별 과목 점수 총계
np.sum(sn)
# Out:
# 1반    271
# 2반    388
# 3반    295
# 4반    243
# dtype: int64

# %%
sn.sum().sort_values(ascending=False)
# Out:
# 2반    388
# 3반    295
# 1반    271
# 4반    243
# dtype: int64

# %%
sn.sum(axis=1)
# Out:
# 과목
# 수학    201
# 영어    282
# 국어    253
# 사회    298
# 과학    163
# dtype: int64

# %%
sn2=sn.transpose()
sn2
# Out:
# 과목  수학  영어  국어  사회  과학
# 1반  45  76  47  92  11
# 2반  44  92  92  81  79
# 3반  73  45  45  85  47
# 4반  39  69  69  40  26

# %%
np.sum(sn2)
# Out:
# 과목
# 수학    201
# 영어    282
# 국어    253
# 사회    298
# 과학    163
# dtype: int64

# %%
# sn['합계']=np.sum[sn.loc[;,;'4반'],axis=1]
sn['합계']=sn.loc[:,:'4반'].sum(axis=1)
sn
# Out:
#     1반  2반  3반  4반   합계
# 과목
# 수학  45  44  73  39  201
# 영어  76  92  45  69  282
# 국어  47  92  45  69  253
# 사회  92  81  85  40  298
# 과학  11  79  47  26  163

# %%
sn['평균']=sn.loc[:,:'4반'].mean(axis=1)
sn
# Out:
#     1반  2반  3반  4반   합계     평균
# 과목
# 수학  45  44  73  39  201  50.25
# 영어  76  92  45  69  282  70.50
# 국어  47  92  45  69  253  63.25
# 사회  92  81  85  40  298  74.50
# 과학  11  79  47  26  163  40.75

# %%
# 인덱스를 추가하는 방법
sn.loc['반평균']=sn.loc[:'과학',:].mean(axis=0)
sn
# Out:
#        1반    2반    3반    4반     합계     평균
# 과목
# 수학   45.0  44.0  73.0  39.0  201.0  50.25
# 영어   76.0  92.0  45.0  69.0  282.0  70.50
# 국어   47.0  92.0  45.0  69.0  253.0  63.25
# 사회   92.0  81.0  85.0  40.0  298.0  74.50
# 과학   11.0  79.0  47.0  26.0  163.0  40.75
# 반평균  54.2  77.6  59.0  48.6  239.4  59.85

# %%
# 과목별로 가장 큰 값과 가장 작은 값의 차이를 구하자

# %%
# 가장 큰 값 구하기
# max()
sn_max=sn.loc[:'과학',:'4반'].max(axis=1)

# %%
# 가장 작은 값 구하기
# min()
sn_min=sn.loc[:'과학',:'4반'].min(axis=1)

# %%
sn_max-sn_min
# Out:
# 과목
# 수학    34.0
# 영어    47.0
# 국어    47.0
# 사회    52.0
# 과학    68.0
# dtype: float64

# %%
# apply()
# 행이나 열 단위로 복잡한 처리를 하고 싶을 때 사용
# 적용시킬 데이터에 행 / 열 단위로 함수를 적용시켜줌

# %%
def max_min(x):
    return x.max()-x.min()

# %%
sn.loc[:'과학',:'4반'].apply(max_min, axis=1)
# Out:
# 과목
# 수학    34.0
# 영어    47.0
# 국어    47.0
# 사회    52.0
# 과학    68.0
# dtype: float64

# %%
sn.loc[:'과학',:'4반'].apply(max_min)
# Out:
# 1반    81.0
# 2반    48.0
# 3반    40.0
# 4반    43.0
# dtype: float64

# %%
# 결측치를 채우는 함수
# 값을 출력하고 저장하지는 않음
# fillna()

# %%
data_dic={'A':[1,3,3,4,4], 'B':[1,2,2,3,3], 'C':[1,2,4,4,5]}
df= pd.DataFrame(data_dic)
df
# Out:
#    A  B  C
# 0  1  1  1
# 1  3  2  2
# 2  3  2  4
# 3  4  3  4
# 4  4  3  5

# %%
df["A"].value_counts()
# Out:
# 3    2
# 4    2
# 1    1
# Name: A, dtype: int64

# %%
df1=df.apply(pd.value_counts)
df1
# Out:
#      A    B    C
# 1  1.0  1.0  1.0
# 2  NaN  2.0  1.0
# 3  2.0  2.0  NaN
# 4  2.0  NaN  2.0
# 5  NaN  NaN  1.0

# %%
df1.fillna(0)
# Out:
#      A    B    C
# 1  1.0  1.0  1.0
# 2  0.0  2.0  1.0
# 3  2.0  2.0  0.0
# 4  2.0  0.0  2.0
# 5  0.0  0.0  1.0

# %%
# 카테고리 데이터 만들기
# cut(데이터, 기분, 라벨)

# %%
# ages 실질적인 데이터 bins 구분할 기준 labels 구분된 이름
ages = [0,2,10,21,23,37,31,61,20,41,32,100]
bins = [0,15,25,35,60,99]
labels = ['미성년자','청년','중년','장년','노년']

# %%
pd.cut(x=ages , bins=bins , labels=labels)
# Out:
# [NaN, '미성년자', '미성년자', '청년', '청년', ..., '노년', '청년', '장년', '중년', NaN]
# Length: 12
# Categories (5, object): ['미성년자' < '청년' < '중년' < '장년' < '노년']

# %%
# 데이터프레임 합치기
# concat()

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'], 
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                   index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                   index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'],
                    'D': ['D8', 'D9', 'D10', 'D11']},
                   index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
result=pd.concat([df1,df2,df3], axis=0)
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'], 
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                   index=[2, 3, 6, 7])
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
pd.concat([df1,df4], axis=0)
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 2  NaN  B2  NaN  D2   F2
# 3  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
pd.concat([df1,df4], axis=1)
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
pd.concat([df1,df4],axis=1, join='inner')
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %%
# 인덱스 초기화
pd.concat([df1,df4], axis=1, ignore_index=True)
# Out:
#      0    1    2    3    4    5    6
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
pd.concat([df1,df4], ignore_index=True)
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 4  NaN  B2  NaN  D2   F2
# 5  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
# value를 기준으로 데이터 합치기
df5 = pd.DataFrame({'key': ['K0','K2','K3','K4'],
'A':['A0','A1','A2','A3'],
'B':['B0','B1','B2','B3']})


df6 = pd.DataFrame({'key': ['K0','K1','K2','K3'],
'C':['C0','C1','C2','C3'],
'D':['D0','D1','D2','D3']})

# %%
df5
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K2  A1  B1
# 2  K3  A2  B2
# 3  K4  A3  B3

# %%
df6
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
# merge
# 데이터를 기준으로 df 합침
# on='key' 기준('key') 컬럼에서 같을 때
# 기준이 같은 것 만 출력 : how = inner
pd.merge(df5,df6,on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K2  A1  B1  C2  D2
# 2  K3  A2  B2  C3  D3

# %%
# 모든 데이터 출력 
pd.merge(df5,df6,how='outer')
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0   C0   D0
# 1  K2   A1   B1   C2   D2
# 2  K3   A2   B2   C3   D3
# 3  K4   A3   B3  NaN  NaN
# 4  K1  NaN  NaN   C1   D1

# %%
# how : left, right
pd.merge(df5,df6,how='left')
# Out:
#   key   A   B    C    D
# 0  K0  A0  B0   C0   D0
# 1  K2  A1  B1   C2   D2
# 2  K3  A2  B2   C3   D3
# 3  K4  A3  B3  NaN  NaN

# %%
pd.merge(df5,df6,how='right')
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K1  NaN  NaN  C1  D1
# 2  K2   A1   B1  C2  D2
# 3  K3   A2   B2  C3  D3

# %%
df2015=pd.read_csv('2015.csv', encoding='euc-kr', index_col ='관서명')
df2015
# Out:
#             구분  살인  강도  강간·강제추행    절도     폭력
# 관서명
# 광주지방경찰청계  발생건수  18  44      750  8425   9593
# 광주지방경찰청계  검거건수  18  47      758  5409   8301
# 광주지방경찰청계  검거인원  17  66      776  3433  11774
# 광주지방경찰청계    구속   9  33       42   104     58
# 광주지방경찰청계   불구속   1  26      511  2781   5618
# 광주지방경찰청계    기타   7   7      223   548   6098
# 광주동부경찰서   발생건수   3   5       92  1100   1155
# 광주동부경찰서   검거건수   4   6       86   583    970
# 광주동부경찰서   검거인원   4   7       98   447   1483
# 광주동부경찰서     구속   3   2        8    13     10
# 광주동부경찰서    불구속   0   4       63   379    703
# 광주동부경찰서     기타   1   1       27    55    770
# 광주서부경찰서   발생건수   5  10      172  2050   2483
# 광주서부경찰서   검거건수   4   8      153  1471   2124
# 광주서부경찰서   검거인원   4  15      167   876   3080
# 광주서부경찰서     구속   3  10        7    27     19
# 광주서부경찰서    불구속   0   5       91   665   1366
# 광주서부경찰서     기타   1   0       69   184   1695
# 광주남부경찰서   발생건수   1   3       70   962   1081
# 광주남부경찰서   검거건수   1   3       53   506    941
# 광주남부경찰서   검거인원   1   3       52   418   1260
# 광주남부경찰서     구속   0   3        3    19      3
# 광주남부경찰서    불구속   1   0       39   325    675
# 광주남부경찰서     기타   0   0       10    74    582
# 광주북부경찰서   발생건수   5  14      256  2570   2621
# 광주북부경찰서   검거건수   5  18      212  1852   2319
# 광주북부경찰서   검거인원   5  28      216   948   3168
# 광주북부경찰서     구속   3  11       11    30     10
# 광주북부경찰서    불구속   0  12      153   770   1544
# 광주북부경찰서     기타   2   5       52   148   1614
# 광주광산경찰서   발생건수   4  12      160  1743   2253
# 광주광산경찰서   검거건수   4  10      135   996   1922
# 광주광산경찰서   검거인원   3   8      129   736   2585
# 광주광산경찰서     구속   0   4        5    12      6
# 광주광산경찰서    불구속   0   4       81   639   1181
# 광주광산경찰서     기타   3   0       43    85   1398

# %%
df2016=pd.read_csv('2016.csv', encoding='euc-kr', index_col='관서명')
df2016
# Out:
#             구분  살인  강도  강간·강제추행    절도     폭력
# 관서명
# 광주지방경찰청계  발생건수  17  47      701  6052   8599
# 광주지방경찰청계  검거건수  18  47      713  4242   7631
# 광주지방경찰청계  검거인원  21  54      758  3455  10747
# 광주지방경찰청계    구속  14  25       37   132     57
# 광주지방경찰청계   불구속   3  25      491  2862   5267
# 광주지방경찰청계    기타   4   4      230   461   5423
# 광주동부경찰서   발생건수   3   8       83   832   1142
# 광주동부경찰서   검거건수   3   7       70   679   1002
# 광주동부경찰서   검거인원   4  10       71   543   1497
# 광주동부경찰서     구속   2   2        3    17      7
# 광주동부경찰서    불구속   0   7       50   460    773
# 광주동부경찰서     기타   2   1       18    66    717
# 광주서부경찰서   발생건수   2  11      174  1417   2288
# 광주서부경찰서   검거건수   3  11      158   963   1994
# 광주서부경찰서   검거인원   3  13      169   894   2874
# 광주서부경찰서     구속   3   6        7    22     18
# 광주서부경찰서    불구속   0   4       92   749   1301
# 광주서부경찰서     기타   0   3       70   123   1555
# 광주남부경찰서   발생건수   1   4       64   768   1028
# 광주남부경찰서   검거건수   1   4       54   544    883
# 광주남부경찰서   검거인원   1   5       55   348   1198
# 광주남부경찰서     구속   1   4        2    12      2
# 광주남부경찰서    불구속   0   1       38   264    599
# 광주남부경찰서     기타   0   0       15    72    597
# 광주북부경찰서   발생건수   6   7      205  1788   2142
# 광주북부경찰서   검거건수   5   8      158  1156   1906
# 광주북부경찰서   검거인원   6  10      178   933   2700
# 광주북부경찰서     구속   3   6        1    50     13
# 광주북부경찰서    불구속   2   4      135   759   1402
# 광주북부경찰서     기타   1   0       42   124   1285
# 광주광산경찰서   발생건수   5  17      175  1247   1999
# 광주광산경찰서   검거건수   5  17      147   898   1798
# 광주광산경찰서   검거인원   6  16      147   723   2382
# 광주광산경찰서     구속   4   7       14    31      7
# 광주광산경찰서    불구속   1   9       85   620   1125
# 광주광산경찰서     기타   1   0       48    72   1250

# %%
df2017=pd.read_csv('2017.csv', encoding='euc-kr', index_col='관서명')
df2017
# Out:
#             구분  살인  강도  강간·강제추행    절도     폭력
# 관서명
# 광주지방경찰청계  발생건수   9  33      725  4816   8366
# 광주지방경찰청계  검거건수   9  32      732  3487   7553
# 광주지방경찰청계  검거인원  10  61      824  3046  11018
# 광주지방경찰청계    구속   8  28       71   115     88
# 광주지방경찰청계   불구속   0  26      523  2493   5235
# 광주지방경찰청계    기타   2   7      230   438   5695
# 광주지방경찰청   발생건수   0   0        0     0      0
# 광주지방경찰청   검거건수   0   1       91     0     37
# 광주지방경찰청   검거인원   0   1      105     0    149
# 광주지방경찰청     구속   0   0       17     0      7
# 광주지방경찰청    불구속   0   1       53     0     69
# 광주지방경찰청     기타   0   0       35     0     73
# 광주동부경찰서   발생건수   3   5       77   624   1090
# 광주동부경찰서   검거건수   3   5       70   470    953
# 광주동부경찰서   검거인원   4   4       76   483   1538
# 광주동부경찰서     구속   2   3        2    19      9
# 광주동부경찰서    불구속   0   1       57   395    801
# 광주동부경찰서     기타   2   0       17    69    728
# 광주서부경찰서   발생건수   0   7      196  1142   2293
# 광주서부경찰서   검거건수   0   7      172   708   2065
# 광주서부경찰서   검거인원   0  23      188   708   2971
# 광주서부경찰서     구속   0   8        6    20     31
# 광주서부경찰서    불구속   0  15      123   582   1356
# 광주서부경찰서     기타   0   0       59   106   1584
# 광주남부경찰서   발생건수   0   4       68   577    898
# 광주남부경찰서   검거건수   0   4       51   522    799
# 광주남부경찰서   검거인원   0   5       47   363   1107
# 광주남부경찰서     구속   0   2        1    18      1
# 광주남부경찰서    불구속   0   2       29   271    591
# 광주남부경찰서     기타   0   1       17    74    515
# 광주북부경찰서   발생건수   3   5      215  1546   2176
# 광주북부경찰서   검거건수   3   5      204  1127   1997
# 광주북부경찰서   검거인원   3   6      260   898   2863
# 광주북부경찰서     구속   3   4       39    33     22
# 광주북부경찰서    불구속   0   0      159   730   1314
# 광주북부경찰서     기타   0   2       62   135   1527
# 광주광산경찰서   발생건수   3  12      169   927   1909
# 광주광산경찰서   검거건수   3  10      144   660   1702
# 광주광산경찰서   검거인원   3  22      148   594   2390
# 광주광산경찰서     구속   3  11        6    25     18
# 광주광산경찰서    불구속   0   7      102   515   1104
# 광주광산경찰서     기타   0   4       40    54   1268

# %% [markdown]
# #cp949 언어

# %%
df2017.
# Out:
#             구분  살인  강도  강간·강제추행    절도     폭력
# 관서명
# 광주지방경찰청계  발생건수   9  33      725  4816   8366
# 광주지방경찰청계  검거건수   9  32      732  3487   7553
# 광주지방경찰청계  검거인원  10  61      824  3046  11018
# 광주지방경찰청계    구속   8  28       71   115     88
# 광주지방경찰청계   불구속   0  26      523  2493   5235
# 광주지방경찰청계    기타   2   7      230   438   5695
# 광주지방경찰청   발생건수   0   0        0     0      0
# 광주지방경찰청   검거건수   0   1       91     0     37
# 광주지방경찰청   검거인원   0   1      105     0    149
# 광주지방경찰청     구속   0   0       17     0      7

# %%
# 2017년에만 있는 데이터 삭제하기
# drop
# 1. 변수에 담기
# 2. inplace=True 존재한다면 변수에 담긴 데이터를 변경
df2017.drop('광주지방경찰청', inplace=True)

# %%
# 컬럼(열)을 삭제 - drop( ... ,axis=1)
df2017.drop('구분', axis=1)
# Out:
#           살인  강도  강간·강제추행    절도     폭력
# 관서명
# 광주지방경찰청계   9  33      725  4816   8366
# 광주지방경찰청계   9  32      732  3487   7553
# 광주지방경찰청계  10  61      824  3046  11018
# 광주지방경찰청계   8  28       71   115     88
# 광주지방경찰청계   0  26      523  2493   5235
# 광주지방경찰청계   2   7      230   438   5695
# 광주동부경찰서    3   5       77   624   1090
# 광주동부경찰서    3   5       70   470    953
# 광주동부경찰서    4   4       76   483   1538
# 광주동부경찰서    2   3        2    19      9
# 광주동부경찰서    0   1       57   395    801
# 광주동부경찰서    2   0       17    69    728
# 광주서부경찰서    0   7      196  1142   2293
# 광주서부경찰서    0   7      172   708   2065
# 광주서부경찰서    0  23      188   708   2971
# 광주서부경찰서    0   8        6    20     31
# 광주서부경찰서    0  15      123   582   1356
# 광주서부경찰서    0   0       59   106   1584
# 광주남부경찰서    0   4       68   577    898
# 광주남부경찰서    0   4       51   522    799
# 광주남부경찰서    0   5       47   363   1107
# 광주남부경찰서    0   2        1    18      1
# 광주남부경찰서    0   2       29   271    591
# 광주남부경찰서    0   1       17    74    515
# 광주북부경찰서    3   5      215  1546   2176
# 광주북부경찰서    3   5      204  1127   1997
# 광주북부경찰서    3   6      260   898   2863
# 광주북부경찰서    3   4       39    33     22
# 광주북부경찰서    0   0      159   730   1314
# 광주북부경찰서    0   2       62   135   1527
# 광주광산경찰서    3  12      169   927   1909
# 광주광산경찰서    3  10      144   660   1702
# 광주광산경찰서    3  22      148   594   2390
# 광주광산경찰서    3  11        6    25     18
# 광주광산경찰서    0   7      102   515   1104
# 광주광산경찰서    0   4       40    54   1268

# %%
# '발생건수'에 해당하는 데이터가 필요하다
df2015.head(10)
# Out:
#             구분  살인  강도  강간·강제추행    절도     폭력
# 관서명
# 광주지방경찰청계  발생건수  18  44      750  8425   9593
# 광주지방경찰청계  검거건수  18  47      758  5409   8301
# 광주지방경찰청계  검거인원  17  66      776  3433  11774
# 광주지방경찰청계    구속   9  33       42   104     58
# 광주지방경찰청계   불구속   1  26      511  2781   5618
# 광주지방경찰청계    기타   7   7      223   548   6098
# 광주동부경찰서   발생건수   3   5       92  1100   1155
# 광주동부경찰서   검거건수   4   6       86   583    970
# 광주동부경찰서   검거인원   4   7       98   447   1483
# 광주동부경찰서     구속   3   2        8    13     10

# %%
# 불리언(T/F)
df2015['구분']=='발생건수'
# Out:
# 관서명
# 광주지방경찰청계     True
# 광주지방경찰청계    False
# 광주지방경찰청계    False
# 광주지방경찰청계    False
# 광주지방경찰청계    False
# 광주지방경찰청계    False
# 광주동부경찰서      True
# 광주동부경찰서     False
# 광주동부경찰서     False
# 광주동부경찰서     False
# 광주동부경찰서     False
# 광주동부경찰서     False
# 광주서부경찰서      True
# 광주서부경찰서     False
# 광주서부경찰서     False
# 광주서부경찰서     False
# 광주서부경찰서     False
# 광주서부경찰서     False
# 광주남부경찰서      True
# 광주남부경찰서     False
# 광주남부경찰서     False
# 광주남부경찰서     False
# 광주남부경찰서     False
# 광주남부경찰서     False
# 광주북부경찰서      True
# 광주북부경찰서     False
# 광주북부경찰서     False
# 광주북부경찰서     False
# 광주북부경찰서     False
# 광주북부경찰서     False
# 광주광산경찰서      True
# 광주광산경찰서     False
# 광주광산경찰서     False
# 광주광산경찰서     False
# 광주광산경찰서     False
# 광주광산경찰서     False
# Name: 구분, dtype: bool

# %%
# 불리언 인덱싱
df2015_crime=df2015[df2015['구분']=='발생건수'].copy()

# %%
df2016_crime=df2016[df2016['구분']=='발생건수'].copy()

# %%
df2017_crime=df2017[df2017['구분']=='발생건수'].copy()

# %%
df2015_crime.sum(axis=1)
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_7452/192641762.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2015_crime.sum(axis=1)
# 관서명
# 광주지방경찰청계    18830
# 광주동부경찰서      2355
# 광주서부경찰서      4720
# 광주남부경찰서      2117
# 광주북부경찰서      5466
# 광주광산경찰서      4172
# dtype: int64

# %%
df2015_crime['2015총계']=df2015_crime.loc[:,'살인':'폭력'].sum(axis=1)
df2015_crime
# Out:
#             구분  살인  강도  강간·강제추행    절도    폭력  2015총계
# 관서명
# 광주지방경찰청계  발생건수  18  44      750  8425  9593   18830
# 광주동부경찰서   발생건수   3   5       92  1100  1155    2355
# 광주서부경찰서   발생건수   5  10      172  2050  2483    4720
# 광주남부경찰서   발생건수   1   3       70   962  1081    2117
# 광주북부경찰서   발생건수   5  14      256  2570  2621    5466
# 광주광산경찰서   발생건수   4  12      160  1743  2253    4172

# %%
df2016_crime['2016총계']=df2016_crime.loc[:,'살인':'폭력'].sum(axis=1)
df2016_crime
# Out:
#             구분  살인  강도  강간·강제추행    절도    폭력  2016총계
# 관서명
# 광주지방경찰청계  발생건수  17  47      701  6052  8599   15416
# 광주동부경찰서   발생건수   3   8       83   832  1142    2068
# 광주서부경찰서   발생건수   2  11      174  1417  2288    3892
# 광주남부경찰서   발생건수   1   4       64   768  1028    1865
# 광주북부경찰서   발생건수   6   7      205  1788  2142    4148
# 광주광산경찰서   발생건수   5  17      175  1247  1999    3443

# %%
df2017_crime['2017총계']=df2017_crime.loc[:,'살인':'폭력'].sum(axis=1)
df2017_crime
# Out:
#             구분  살인  강도  강간·강제추행    절도    폭력  2017총계
# 관서명
# 광주지방경찰청계  발생건수   9  33      725  4816  8366   13949
# 광주동부경찰서   발생건수   3   5       77   624  1090    1799
# 광주서부경찰서   발생건수   0   7      196  1142  2293    3638
# 광주남부경찰서   발생건수   0   4       68   577   898    1547
# 광주북부경찰서   발생건수   3   5      215  1546  2176    3945
# 광주광산경찰서   발생건수   3  12      169   927  1909    3020

# %%
# t2017 t2016 t2015 변수에 2015 2016 2017 총계 컬럼 담기

# %%
t2017=df2017_crime.loc[:,'2017총계']
t2017
# Out:
# 관서명
# 광주지방경찰청계    13949
# 광주동부경찰서      1799
# 광주서부경찰서      3638
# 광주남부경찰서      1547
# 광주북부경찰서      3945
# 광주광산경찰서      3020
# Name: 2017총계, dtype: int64

# %%
t2016=df2016_crime.loc[:,'2016총계']
t2016
# Out:
# 관서명
# 광주지방경찰청계    15416
# 광주동부경찰서      2068
# 광주서부경찰서      3892
# 광주남부경찰서      1865
# 광주북부경찰서      4148
# 광주광산경찰서      3443
# Name: 2016총계, dtype: int64

# %%
t2015=df2015_crime.loc[:,'2015총계']
t2015
# Out:
# 관서명
# 광주지방경찰청계    18830
# 광주동부경찰서      2355
# 광주서부경찰서      4720
# 광주남부경찰서      2117
# 광주북부경찰서      5466
# 광주광산경찰서      4172
# Name: 2015총계, dtype: int64

# %%
p1=(t2016-t2015)/t2015*100
p2=(t2017-t2016)/t2016*100

# %%
p1.name='2015_2016증감율'
p1
# Out:
# 관서명
# 광주지방경찰청계   -18.130643
# 광주동부경찰서    -12.186837
# 광주서부경찰서    -17.542373
# 광주남부경찰서    -11.903637
# 광주북부경찰서    -24.112697
# 광주광산경찰서    -17.473634
# Name: 2015-2016증감율, dtype: float64

# %%
p2.name='2016-2017증감율'
p2
# Out:
# 관서명
# 광주지방경찰청계    -9.516087
# 광주동부경찰서    -13.007737
# 광주서부경찰서     -6.526208
# 광주남부경찰서    -17.050938
# 광주북부경찰서     -4.893925
# 광주광산경찰서    -12.285797
# Name: 2016-2017증감율, dtype: float64

# %%
pd.concat([t2015, p1,t2016,p2,t2017], axis=1)
# Out:
#           2015총계  2015-2016증감율  2016총계  2016-2017증감율  2017총계
# 관서명
# 광주지방경찰청계   18830    -18.130643   15416     -9.516087   13949
# 광주동부경찰서     2355    -12.186837    2068    -13.007737    1799
# 광주서부경찰서     4720    -17.542373    3892     -6.526208    3638
# 광주남부경찰서     2117    -11.903637    1865    -17.050938    1547
# 광주북부경찰서     5466    -24.112697    4148     -4.893925    3945
# 광주광산경찰서     4172    -17.473634    3443    -12.285797    3020
